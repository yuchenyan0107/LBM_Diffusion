# %%
from dataclasses import dataclass
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

from functions import *

from tqdm import tqdm

# %%
@dataclass
class Config:
    nx: int = 400
    ny: int = 200
    steps: int = 20000
    output_stride: int = 2000
    molecular_weights: tuple[float, float, float] = (30, 30, 30)  # N2, H2, CO2
    # Left half: 50% N2 + 50% H2, Right half: 50% N2 + 50% CO2
    left_frac: tuple[float, float, float] = (0.1, 0.4, 0.5) # pressure fraction
    right_frac: tuple[float, float, float] = (0.1, 0.5, 0.4)
    total_pressure: float = 1.0
    theta: float = 0.5
    nB: int = 15
    frames_dir: str = "demo_frames/three_species_mixing"

# %%
def initialise_chamber(config: Config):
    nx, ny = config.nx, config.ny
    species = 3
    phi = 1.0 / xp.array(config.molecular_weights, dtype=xp.float64)

    # Partial pressures for each species
    psigma = xp.zeros((species, nx, ny), dtype=xp.float64)
    mid = nx // 2
    left = xp.array(config.left_frac, dtype=xp.float64) * config.total_pressure
    right = xp.array(config.right_frac, dtype=xp.float64) * config.total_pressure
    for s in range(species):
        psigma[s, :mid, :] = left[s]
        psigma[s, mid:, :] = right[s]

    # Convert partial pressures to densities: p_s = phi_s * rho_s / 3
    rho_s = xp.zeros_like(psigma)
    for s in range(species):
        rho_s[s] = 3.0 * psigma[s] / phi[s]

    # Initial populations from equilibrium with zero velocity
    f = xp.zeros((species, 9, nx, ny), dtype=xp.float64)
    ux_s = xp.zeros((species, nx, ny), dtype=xp.float64)
    uy_s = xp.zeros((species, nx, ny), dtype=xp.float64)
    feq = equilibrium(f, rho_s, phi, ux_s, uy_s)
    f[...] = feq
    return f, phi

# %%
def main(non_absorb_mask, bc_top, bc_bottom):
    cfg = Config()
    out_dir = 'demo_frames'

    f, phi = initialise_chamber(cfg)
    molecular_weights = xp.array(cfg.molecular_weights, dtype=xp.float64)

    #extra_thickness = []

    for step in tqdm(range(cfg.steps + 1)):
        if step % cfg.output_stride == 0:
            save_concentration_frames(f, phi, step, molecular_weights)

            #thickness = plot_boundary_concentration(f)
            #extra_thickness.append(to_numpy(thickness))
        if step == cfg.steps:
            break
        f = bgk_step(f, molecular_weights, phi, cfg.nB, lattice_stream_BC_full, step,
                     non_absorb_mask, bc_top, bc_bottom)

    print(f"Saved frames to {out_dir}")

    return f#, np.array(extra_thickness)

# %%
def plot_boundary_concentration(f):

    phi = 1.0 / xp.array(Config.molecular_weights, dtype=xp.float64)
    rho_s, ux_s, uy_s, rho_mix, p_mix = calculate_moment(f, phi)

    concentration_profile = to_numpy(rho_s[0, :, 0])
    base_concentration = np.min(concentration_profile)
    extra_thickness = concentration_profile - base_concentration + 1e-4

    normalized_extra_thickness = extra_thickness/base_concentration
    '''
    plt.scatter(np.arange(f.shape[2])[to_numpy(non_absorb_mask) == 0], extra_thickness[to_numpy(non_absorb_mask) == 0], s = 1)
    plt.xlim(0, f.shape[2])
    #plt.xlim(100, 300)
    plt.ylim(bottom = 1e-4)
    plt.yscale('log')
    plt.grid()
    plt.show()
    '''
    '''
    plt.scatter(np.arange(f.shape[2])[to_numpy(non_absorb_mask) == 0], to_numpy(rho_s[0, :, 0])[to_numpy(non_absorb_mask) == 0], s = 1)
    plt.xlim(0, f.shape[2])
    #plt.xlim(100, 300)
    plt.ylim(bottom = 0)
    '''

    return normalized_extra_thickness

# %%
absorption_coefficient = 5e1

non_absorb_mask = xp.zeros(Config.nx, dtype=bool)
gap = 32
width = 40
non_absorb_mask[Config.nx//2 - gap//2 - width: Config.nx//2- gap//2] = True
non_absorb_mask[Config.nx//2 + gap//2 : Config.nx//2 + gap//2 + width] = True

plt.plot(to_numpy(non_absorb_mask))

#bottom boundary
b1 = xp.array([absorption_coefficient, 0, 0]) # 1 / absorption
b2 = xp.array([1, 1, 1])
b3 = xp.array([0, 44.55, 44.55]) # stable concentration
reflection_boundary = np.array([0, 1, 1]) # which component has no-slip wall BC

bc_bottom = (b1, b2, b3, reflection_boundary)

# top boundary
b1 = xp.array([0, 0, 0])
b2 = xp.array([1, 1, 1])
b3 = xp.array([9, 44.55, 44.55])
reflection_boundary = np.array([0, 0, 0])

bc_top = (b1, b2, b3, reflection_boundary)

# %%
#%prun -D mslbm.pstat f = main()
f, extra_thickness = main(non_absorb_mask, bc_top, bc_bottom)
# Out:
#   3%|▎         | 64/2001 [00:02<01:04, 30.24it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 #%prun -D mslbm.pstat f = main()
# ----> 2 f, extra_thickness = main(non_absorb_mask, bc_top, bc_bottom)
#
# Cell In[46], line 18, in main(non_absorb_mask, bc_top, bc_bottom)
#      16     if step == cfg.steps:
#      17         break
# ---> 18     f = bgk_step(f, molecular_weights, phi, cfg.nB, lattice_stream_BC_full, step,
#      19                  non_absorb_mask, bc_top, bc_bottom)
#      21 print(f"Saved frames to {out_dir}")
#      23 return f
#
# File C:\Softwares\LBM_Diffusion\cupy_compatible\functions\MS_LBM_functions.py:447, in bgk_step(f, molecular_weight, phi, nB, stream_fn, step, non_absorb_mask, bc_top, bc_bottom)
#     443 g_dagger_s =calculate_g_dagger(f, feq, lambda_s)
#     445 #################### After streaming ####################
# --> 447 g_streamed = stream_fn(g_dagger_s, phi, step,
#     448                        non_absorb_mask, bc_top, bc_bottom)
#     450 rho_s, ux_s, uy_s, rho_mix, p_mix = calculate_moment(g_streamed, phi)
#     451 m_mix = calculate_m_mix(rho_s, rho_mix, molecular_weight)
#
# File C:\Softwares\LBM_Diffusion\cupy_compatible\functions\MS_LBM_functions.py:66, in lattice_stream_BC_full(g_dagger_s, phi, step, non_absorb_mask, bc_top, bc_bottom)
#      63 # top:
#      64 b1, b2, b3, reflection_boundary = bc_top
# ---> 66 g_streamed = top_bottom_boundary('top', g_streamed, g_dagger_s, phi, b1, b2, b3, reflection_boundary, non_absorb_mask)
#      69 if step % 200 == 0:
#      70     molecular_weight = xp.array([28.0, 2.0, 44.0])
#
# File C:\Softwares\LBM_Diffusion\cupy_compatible\functions\MS_LBM_functions.py:109, in top_bottom_boundary(direction, g_streamed, g_dagger_s, phi, b1, b2, b3, reflection_boundary, non_absorb_mask)
#     106     C_w = (C_f + ne * dx * b3[s] / b1[s] / 2) / (1 + ne * dx * b2[s] / b1[s] / 2)
#     108 # equilibrium based on concentration
# --> 109 f_w_bottom = eq_single_boundary(C_w, phi[s], xp.zeros(g_dagger_s.shape[2]),
#     110                                 xp.zeros(g_dagger_s.shape[2]))
#     112 for i in boundary_indexes:
#     113     g_streamed[s, i, :, row_index] = -g_dagger_s[s, OPPOSITE[i], :, row_index] + 2 * f_w_bottom[i]
#
# File C:\Softwares\LBM_Diffusion\cupy_compatible\functions\MS_LBM_functions.py:190, in eq_single_boundary(C_w, phi_s, ux_star, uy_star)
#     185 u_sq = ux_star ** 2 + uy_star ** 2  # (nx or...y...)
#     186 cu = D2Q9_CX[:, None] * ux_star[None, :] + D2Q9_CY[:, None] * uy_star[None, :]
#     188 f_w_eq = w[:, None] * C_w[None, :] * (
#     189         phi_s
# --> 190         + 3 * cu
#     191         + 4.5 * cu ** 2
#     192         - 1.5 * u_sq
#     193 )
#     195 f_w_eq[0, :] = w[0] * C_w * ((9 - 5 * phi_s) / 4 - 1.5 * u_sq)
#     197 return f_w_eq
#
# File cupy\\_core\\core.pyx:1334, in cupy._core.core._ndarray_base.__mul__()
#
# File cupy\\_core\\_kernel.pyx:1333, in cupy._core._kernel.ufunc.__call__()
#
# File cupy\\_core\\_kernel.pyx:1593, in cupy._core._kernel._Ops.guess_routine()
#
# File cupy\\_core\\_kernel.pyx:1116, in cupy._core._kernel._min_scalar_type()
#
# File ~\anaconda3\Lib\site-packages\numpy\core\multiarray.py:618, in min_scalar_type(a)
#     505     """
#     506     can_cast(from_, to, casting='safe')
#     507
#    (...)
#     613
#     614     """
#     615     return (from_,)
# --> 618 @array_function_from_c_func_and_dispatcher(_multiarray_umath.min_scalar_type)
#     619 def min_scalar_type(a):
#     620     """
#     621     min_scalar_type(a, /)
#     622
#    (...)
#     664
#     665     """
#     666     return (a,)
#
# KeyboardInterrupt:

# %%
thickness_profile = plot_boundary_concentration(f)

# %%
from joblib import Parallel, delayed

def _single_run(absorption_rate):

    absorption_coefficient = 1/absorption_rate

    non_absorb_mask = xp.zeros(Config.nx, dtype=bool)
    gap = 32
    width = 40
    non_absorb_mask[Config.nx//2 - gap//2 - width: Config.nx//2- gap//2] = True
    non_absorb_mask[Config.nx//2 + gap//2 : Config.nx//2 + gap//2 + width] = True
    #plt.plot(to_numpy(non_absorb_mask))
    #bottom boundary
    b1 = xp.array([absorption_coefficient, 0, 0]) # 1 / absorption
    b2 = xp.array([1, 1, 1])
    b3 = xp.array([0, 44.55, 44.55]) # stable concentration
    reflection_boundary = np.array([0, 1, 1]) # which component has no-slip wall BC
    bc_bottom = (b1, b2, b3, reflection_boundary)
    # top boundary
    b1 = xp.array([0, 0, 0])
    b2 = xp.array([1, 1, 1])
    b3 = xp.array([9, 44.55, 44.55])
    reflection_boundary = np.array([0, 0, 0])
    bc_top = (b1, b2, b3, reflection_boundary)

    f = main(non_absorb_mask, bc_top, bc_bottom)
    thickness_profile = plot_boundary_concentration(f)

    return thickness_profile

def parameter_sweep_parallel(num, n_jobs=2, backend="loky"):
    a = np.linspace(-3.5, -0.5, num = num, endpoint = True)
    absorption_rates = np.power(10, a)

    results = Parallel(n_jobs=n_jobs, backend=backend)(
        delayed(_single_run)(absorption_rate)
        for absorption_rate in absorption_rates
    )

    thickness_profile = results
    return absorption_rates, thickness_profile

# %%
absorption_rates, thickness_profile = parameter_sweep_parallel(num = 10, n_jobs=5, backend="loky")
# n = 3, 47 min
# n = 5,

# %%
print(1/absorption_rates)
for i in range(10):
    plt.plot(np.arange(f.shape[2])[to_numpy(non_absorb_mask) == 0], thickness_profile[i][to_numpy(non_absorb_mask) == 0], label = 1/absorption_rates[i])
plt.yscale('log')
plt.legend()
# Out:
#   Cell In[88], line 3
#     plt.plot(np.arange(f.shape[2])[to_numpy(non_absorb_mask) == 0], thickness_profile[i][to_numpy(non_absorb_mask) == 0], label = f"{1/absorption_rates[i].2f}")
#                                                                                                                                                            ^
# SyntaxError: invalid decimal literal
